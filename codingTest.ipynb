# %%
import math
import numpy as np

# %%
def solution(id_list, report, k):
    divide_report_reported(id_list, report, k)
# Out:
#   Input In [13]
#     def split_name(report):
#     ^
# IndentationError: expected an indented block

# %%
def divide_report_reported(id_list, report, k):
    name_list = []
    for i in report: 
        split = i.split()
        for i in split: 
            name_list.append(i)
    
    reporter = []
    reported = []

    count = 0
    for i in name_list: 
        if count % 2 == 0 :
            reporter.append(i)
        else : 
            reported.append(i)
        count += 1
    
    print("reporter :: ", reporter)
    print("reported :: ", reported)

    # dict = {reporter[i] : reported[i] for i in range(0, len(reporter))}

    # print("dict :: ", dict)

    reported_count_dict = {}
    for i in reported_count_dict:
        try : reported_count_dict[i] += 1
        except : reported_count_dict[i] = 1
    
    # print("count :: ", count)

    for i in range(0, len(id_list)):
        a = reporter.index(id_list[i])
    print(a)

# %%
divide_report_reported(["chandler", "pheobe"], ["monica rachel", "chandler joey", "pheobe ross", "rachel ross", "chandler ross", "pheobe rachel"], 2)
# Out:
# reporter ::  ['monica', 'chandler', 'pheobe', 'rachel', 'chandler', 'pheobe']
# reported ::  ['rachel', 'joey', 'ross', 'ross', 'ross', 'rachel']
# 2
